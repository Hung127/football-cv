# %%
# make sure that you installed roboflow and ultralytics
# !pip install roboflow ultralytics

# %% [markdown]
# # Get the dataset from roboflow

# %%
import os
from pathlib import Path
from dotenv import load_dotenv

project_root = Path(os.getcwd()).parent 
# print(project_root)

# %%
from roboflow import Roboflow

# Load variables from the .env file
load_dotenv(project_root)

roboflow_api_key = os.getenv("ROBOFLOW_API_KEY")

rf = Roboflow(api_key=roboflow_api_key)
project = rf.workspace("roboflow-jvuqo").project("football-players-detection-3zvbc")
version = project.version(1)
dataset = version.download("yolo26")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to football-players-detection-1 in yolo26:: 100%|█████| 1338/1338 [00:00<00:00, 2612.68it/s]

# %%
dataset.location
import shutil
target_dirs = ['train', 'test', 'valid']
for target_dir in target_dirs:
    shutil.move(f'football-players-detection-1/{target_dir}', f'football-players-detection-1/football-players-detection-1/{target_dir}')
